# %%
from datasets import load_dataset

# %%
print("Loading dataset...")
ds = load_dataset("pkuHaowei/llm-srbench", "lsr_synth_matsci")
# Out:
# Loading dataset...

# %%
ds["train"].to_csv("lsr_synth_matsci_train.csv")
# Out:
# Creating CSV from Arrow format: 100%|██████████| 1/1 [00:01<00:00,  1.61s/ba]
# 803092

# %%
import pandas as pd
df = pd.read_csv("lsr_synth_matsci_train.csv")

# %%
df.head()
# Out:
#                 instance_id  \
# 0  lsr_synth_matsci_matsci0
# 1  lsr_synth_matsci_matsci1
# 2  lsr_synth_matsci_matsci2
# 3  lsr_synth_matsci_matsci3
# 4  lsr_synth_matsci_matsci4
#
#                                          description  \
# 0  Discover the mathematical equation relating th...
# 1  Discover the mathematical equation relating th...
# 2  Discover the mathematical equation relating th...
# 3  Discover the mathematical equation relating th...
# 4  Discover the mathematical equation relating th...
#
#                                          train_input  \
# 0  [array([3.04140836e-01, 4.25070404e+02])\n arr...
# 1  [array([6.91338256e-02, 3.07566925e+02])\n arr...
# 2  [array([7.20144017e-03, 2.76600708e+02])\n arr...
# 3  [array([1.13662735e-01, 3.29831360e+02])\n arr...
# 4  [array([9.31386277e-02, 3.19569305e+02])\n arr...
#
#                                         train_output  \
# 0  [array([124.36534882]) array([5.08465195]) arr...
# ...

# %%
print("Available columns:", df.columns.tolist())
print("Available instance_ids:", df["instance_id"].head())
# Out:
# Available columns: ['instance_id', 'description', 'train_input', 'train_output', 'test_input', 'test_output', 'input_vars', 'output_vars', 'gt_expression', 'symbols', 'subset']
# Available instance_ids: 0    lsr_synth_matsci_matsci0
# 1    lsr_synth_matsci_matsci1
# 2    lsr_synth_matsci_matsci2
# 3    lsr_synth_matsci_matsci3
# 4    lsr_synth_matsci_matsci4
# Name: instance_id, dtype: object
