# %%
import sys
import os

sys.path.append(os.path.abspath("../.."))

# %%
from app.tools.Sandbox import interpreter

# %%
interpreter("print(1+2)")
# Out:
# {'execution_id': 'c997c896-23cb-48ca-a0c5-e2d081ee4784',
#  'timestamp': '2026-02-27T09:20:42.896171',
#  'input_code': 'print(1+2)',
#  'stdout': ['3\n'],
#  'stderr': [],
#  'saved_files': []}

# %%
# main.py
from dotenv import load_dotenv
load_dotenv()
from e2b_code_interpreter import Sandbox

sbx = Sandbox.create() # By default the sandbox is alive for 5 minutes
execution = sbx.run_code("print(1+2)") # Execute Python inside the sandbox
print(execution.logs)

files = sbx.files.list("/")
print(files)
# Out:
# Logs(stdout: ['3\n'], stderr: [])
# [EntryInfo(name='.e2b', type=<FileType.FILE: 'file'>, path='/.e2b', size=107, mode=420, permissions='-rw-r--r--', owner='root', group='root', modified_time=datetime.datetime(2026, 2, 12, 16, 50, 3, 808178), symlink_target=None), EntryInfo(name='bin', type=<FileType.DIR: 'dir'>, path='/bin', size=7, mode=493, permissions='Lrwxrwxrwx', owner='root', group='root', modified_time=datetime.datetime(2025, 8, 24, 16, 20), symlink_target='/usr/bin'), EntryInfo(name='boot', type=<FileType.DIR: 'dir'>, path='/boot', size=4096, mode=493, permissions='drwxr-xr-x', owner='root', group='root', modified_time=datetime.datetime(2025, 11, 6, 13, 3, 39), symlink_target=None), EntryInfo(name='code', type=<FileType.DIR: 'dir'>, path='/code', size=4096, mode=511, permissions='drwxrwxrwx', owner='root', group='root', modified_time=datetime.datetime(2025, 11, 11, 17, 44, 29, 980296), symlink_target=None), EntryInfo(name='dev', type=<FileType.DIR: 'dir'>, path='/dev', size=2600, mode=493, permissions='drwxr-xr-x', owner='root', group='root', modified_time=datetime.datetime(2026, 2, 12, 16, 50, 3, 673638), symlink_target=None), EntryInfo(name='etc', type=<FileType.DIR: 'dir'>, path='/etc', size=4096, mode=493, permissions='drwxr-xr-x', owner='root', group='root', modified_time=datetime.datetime(2026, 2, 12, 16, 50, 3, 928178), symlink_target=None), EntryInfo(name='home', type=<FileType.DIR: 'dir'>, path='/home', size=4096, mode=493, permissions='drwxr-xr-x', owner='root', group='root', modified_time=datetime.datetime(2025, 11, 6, 13, 4, 24, 197557), symlink_target=None), EntryInfo(name='lib', type=<FileType.DIR: 'dir'>, path='/lib', size=7, mode=493, permissions='Lrwxrwxrwx', owner='root', group='root', modified_time=datetime.datetime(2025, 8, 24, 16, 20), symlink_target='/usr/lib'), EntryInfo(name='lib64', type=<FileType.DIR: 'dir'>, path='/lib64', size=9, mode=493, permissions='Lrwxrwxrwx', owner='root', group='root', modified_time=datetime.datetime(2025, 8, 24, 16, 20), symlink_target='/usr/lib64'), EntryInfo(name='lost+found', type=<FileType.DIR: 'dir'>, path='/lost+found', size=16384, mode=448, permissions='drwx------', owner='root', group='root', modified_time=datetime.datetime(2025, 11, 6, 13, 3, 20), symlink_target=None), EntryInfo(name='media', type=<FileType.DIR: 'dir'>, path='/media', size=4096, mode=493, permissions='drwxr-xr-x', owner='root', group='root', modified_time=datetime.datetime(2025, 11, 6, 13, 3, 39), symlink_target=None), EntryInfo(name='mnt', type=<FileType.DIR: 'dir'>, path='/mnt', size=4096, mode=493, permissions='drwxr-xr-x', owner='root', group='root', modified_time=datetime.datetime(2025, 11, 6, 13, 3, 39), symlink_target=None), EntryInfo(name='opt', type=<FileType.DIR: 'dir'>, path='/opt', size=4096, mode=493, permissions='drwxr-xr-x', owner='root', group='root', modified_time=datetime.datetime(2025, 11, 11, 17, 42, 20, 473783), symlink_target=None), EntryInfo(name='proc', type=<FileType.DIR: 'dir'>, path='/proc', size=0, mode=365, permissions='dr-xr-xr-x', owner='root', group='root', modified_time=datetime.datetime(2026, 2, 12, 16, 50, 2, 265638), symlink_target=None), EntryInfo(name='root', type=<FileType.DIR: 'dir'>, path='/root', size=4096, mode=448, permissions='drwx------', owner='root', group='root', modified_time=datetime.datetime(2025, 11, 11, 17, 43, 37, 44143), symlink_target=None), EntryInfo(name='run', type=<FileType.DIR: 'dir'>, path='/run', size=420, mode=493, permissions='drwxr-xr-x', owner='root', group='root', modified_time=datetime.datetime(2026, 2, 12, 16, 50, 3, 900178), symlink_target=None), EntryInfo(name='sbin', type=<FileType.DIR: 'dir'>, path='/sbin', size=8, mode=493, permissions='Lrwxrwxrwx', owner='root', group='root', modified_time=datetime.datetime(2025, 8, 24, 16, 20), symlink_target='/usr/sbin'), EntryInfo(name='srv', type=<FileType.DIR: 'dir'>, path='/srv', size=4096, mode=493, permissions='drwxr-xr-x', owner='root', group='root', modified_time=datetime.datetime(2025, 11, 6, 13, 3, 39), s ...

# %%
1+2
# Out:
# 3
